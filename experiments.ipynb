# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
import pickle
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.preprocessing import StandardScaler,LabelEncoder
#
# File c:\Data science\ANN end to end project\.venv\lib\site-packages\pandas\__init__.py:31
#      28         _missing_dependencies.append(f"{_dependency}: {_e}")
#      30 if _missing_dependencies:  # pragma: no cover
# ---> 31     raise ImportError(
#      32         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      33     )
#      34 del _hard_dependencies, _dependency, _missing_dependencies
#      36 try:
#      37     # numpy compat
#
# ImportError: Unable to import required dependencies:
# numpy: Error importing numpy: you should not try to import numpy from
# ...

# %%
data=pd.read_csv('Churn_Modelling.csv')
data.head()

# %%
##Preprocess the data and drop irrelevant columns
